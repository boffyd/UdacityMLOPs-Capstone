# %% [markdown]
# # Azure Machine Learning Engineer
# ## Project 3 - Capstone
#
# ## Create a workspace
# In this step we are making an Azure Workspace and setting up an experiment

# %%
# Create a new workspace and define an experiment.

from azureml.core import Workspace, Experiment

#ws = Workspace.get(name="udacity-project")
ws = Workspace.from_config()
ws.get_details()

# Choose a name for the experiment
experiment_name = 'udacity-project-hyperdrive'
experiment = Experiment(workspace=ws, name = experiment_name)

print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep = '\n')

run = experiment.start_logging()
# Out:
# Workspace name: quick-starts-ws-146436
# Azure region: southcentralus
# Subscription id: f5091c60-1c3c-430f-8d81-d802f6bf2414
# Resource group: aml-quickstarts-146436

# %% [markdown]
# ## Create an environment
# Define a conda environment YAML file with your training script dependencies and create an Azure ML environment.

# %%
# %%writefile conda_dependencies.yml
#
# dependencies:
# - python=3.6.2
# - scikit-learn
# - pip:
#   - azureml-defaults
#   - xgboost
# Out:
# Writing conda_dependencies.yml

# %%
from azureml.core import Workspace, Environment

ws = Workspace.from_config()
myenv = Environment.get(workspace=ws, name="AzureML-Minimal")
sklearn_env = Environment.from_conda_specification(name = 'sklearn-env', file_path = './conda_dependencies.yml')

# %% [markdown]
# ### Setup Compute
# Create a new compute or use an existing one if its present

# %%
# Create a compute cluster to provision VM Resources.

from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

# TODO: Create compute cluster
# Use vm_size = "Standard_D2_V2" in your provisioning configuration.
# max_nodes should be no greater than 4.

# Choose a name for the cluster
cpu_cluster_name = 'cpu-cluster-01'

#Verify that the culster does not exist already
try:
    compute_target = ComputeTarget(workspace = ws, name = cpu_cluster_name)
    print('Found existing cluster, use it')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size = 'STANDARD_D2_V2', max_nodes = 4)
    compute_target = ComputeTarget.create(ws, cpu_cluster_name, compute_config)

compute_target.wait_for_completion(show_output = True)
# Out:
# Creating.........
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Dataset

# %%
# azureml-core of version 1.0.72 or higher is required
# azureml-dataprep[pandas] of version 1.1.34 or higher is required
from azureml.core import Workspace, Dataset

subscription_id = 'f5091c60-1c3c-430f-8d81-d802f6bf2414'
resource_group = 'aml-quickstarts-146436'
workspace_name = 'quick-starts-ws-146436'

workspace = Workspace(subscription_id, resource_group, workspace_name)

dataset = Dataset.get_by_name(workspace, name='Adult')

ds = dataset.to_pandas_dataframe()

# %% [markdown]
# ## Hyperdrive Configuration

# %%
# Setup Hyperparameter Tuning with Hyperdrive.

from azureml.widgets import RunDetails
from azureml.train.sklearn import SKLearn
from azureml.train.hyperdrive.run import PrimaryMetricGoal
from azureml.train.hyperdrive.policy import BanditPolicy
from azureml.train.hyperdrive.sampling import RandomParameterSampling
from azureml.train.hyperdrive.runconfig import HyperDriveConfig
from azureml.train.hyperdrive.parameter_expressions import uniform,choice
import os
import shutil
from azureml.core import ScriptRunConfig

#Define the parameter search space/method
# Specify parameter sampler, in this case we are looking to get defined ranges and pass back to the SKILEARN
# training model.


ps = RandomParameterSampling({
    'max_depth' : choice(2,5), #limited for simplicity
    'learning_rate' : choice (1,10) #limited for simplicity
})

# Specify an early termination Policy
# Other options are median policy, have stuck with bandit for simplification
# Bandit policy stops if its less than 10% of best model, starting and interval 5
early_termination_policy = BanditPolicy(slack_factor = 0.1, evaluation_interval=1, delay_evaluation=5)

#creates a training director.
if "training" not in os.listdir():
    os.mkdir("./training")
    
script_folder = './training'

os.makedirs(script_folder, exist_ok = True)

shutil.copy('./train.py',script_folder)

# Create a SKLearn estimator for use with train.py ### YOUR CODE HERE ###
est = SKLearn(source_directory = script_folder,
              entry_script ='train.py',
              compute_target = compute_target,
              vm_size = 'Standard_d2_v',
              conda_packages=['py-xgboost'])



# Set compute target

#script_run_config.run_config.target = compute_target

hyperdrive_config = HyperDriveConfig(estimator = est,
                                     hyperparameter_sampling = ps,
                                     policy = early_termination_policy,
                                     primary_metric_name = 'Accuracy', #Accuracy for classification
                                     primary_metric_goal = PrimaryMetricGoal.MAXIMIZE,
                                     max_total_runs = 50,
                                     max_concurrent_runs = 4)
# Out:
# 'SKLearn' estimator is deprecated. Please use 'ScriptRunConfig' from 'azureml.core.script_run_config' with your own defined environment or the AzureML-Tutorial curated environment.
# 'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.

# %% [markdown]
# ## Run Details

# %%
# Submit your hyperdrive run to the experiment and show run details with the widget.
from azureml.widgets import RunDetails
from azureml.core.experiment import Experiment

#experiment = Experiment(ws, experiment_name)
hyperdrive_run = experiment.submit(hyperdrive_config, show_output = True)

RunDetails(hyperdrive_run).show()
# Out:
# WARNING:root:If 'script' has been provided here and a script file name has been specified in 'run_config', 'script' provided in ScriptRunConfig initialization will take precedence.
# _HyperDriveWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO'…

# %%
src = ScriptRunConfig(source_directory = script_folder,
                      script='train.py',
                      compute_target=compute_target,
                      environment = sklearn_env)


# sklearn_env
# myenv

# %%
run = experiment.submit(src)

# %%
RunDetails(run).show()
# Out:
# _UserRunWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', '…

# %%
run.wait_for_completion(show_output=True)
# Out:
# RunId: udacity-project-hyperdrive_1622713021_9df35139
# Web View: https://ml.azure.com/runs/udacity-project-hyperdrive_1622713021_9df35139?wsid=/subscriptions/f5091c60-1c3c-430f-8d81-d802f6bf2414/resourcegroups/aml-quickstarts-146436/workspaces/quick-starts-ws-146436&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
#
# 2021/06/03 09:37:07 Downloading source code...
# 2021/06/03 09:37:08 Finished downloading source code
# 2021/06/03 09:37:09 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/06/03 09:37:09 Successfully set up Docker network: acb_default_network
# 2021/06/03 09:37:09 Setting up Docker configuration...
# 2021/06/03 09:37:10 Successfully set up Docker configuration
# 2021/06/03 09:37:10 Logging in to registry: 07cc2896cc2c4ad8ac118370e8d5b86f.azurecr.io
# 2021/06/03 09:37:11 Successfully logged into 07cc2896cc2c4ad8ac118370e8d5b86f.azurecr.io
# 2021/06/03 09:37:11 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/03 09:37:11 Scanning for dependencies...
# 2021/06/03 09:37:12 Successfully scanned dependencies
# 2021/06/03 09:37:12 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210301.v1@sha256:9c4f76b334a5add8bd2862ff33289658d267ba298f2d2424fa1a28a4e4cc2232
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210301.v1@sha256:9c4f76b334a5add8bd2862ff33289658d267ba298f2d2424fa1a28a4e4cc2232: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# d519e2592276: Pulling fs layer
# d22d2dfcfa9c: Pulling fs layer
# b3afe92c540b: Pulling fs layer
# b45c209a4d67: Pulling fs layer
# 3f5a608df989: Pulling fs layer
# 11df60c3c446: Pulling fs layer
# 3306300f7441: Pulling fs layer
# d5f61fd90197: Pulling fs layer
# 3c91cee49561: Pulling fs layer
# 3166a3588baf: Pulling fs layer
# 386667a0fc79: Pulling fs layer
# b45c209a4d67: Waiting
# 3f5a608df989: Waiting
# 11df60c3c446: Waiting
# 3306300f7441: Waiting
# d5f61fd90197: Waiting
# 3c91cee49561: Waiting
# 3166a3588baf: Waiting
# 386667a0fc79: Waiting
# d22d2dfcfa9c: Verifying Checksum
# d22d2dfcfa9c: Download complete
# b3afe92c540b: Verifying Checksum
# b3afe92c540b: Download complete
# 3f5a608df989: Verifying Checksum
# 3f5a608df989: Download complete
# 11df60c3c446: Verifying Checksum
# 11df60c3c446: Download complete
# 3306300f7441: Verifying Checksum
# 3306300f7441: Download complete
# d519e2592276: Verifying Checksum
# d519e2592276: Download complete
# d5f61fd90197: Verifying Checksum
# d5f61fd90197: Download complete
# d519e2592276: Pull complete
# d22d2dfcfa9c: Pull complete
# b3afe92c540b: Pull complete
# 3c91cee49561: Verifying Checksum
# 3c91cee49561: Download complete
# b45c209a4d67: Verifying Checksum
# b45c209a4d67: Download complete
# 3166a3588baf: Verifying Checksum
# 3166a3588baf: Download complete
# 386667a0fc79: Verifying Checksum
# 386667a0fc79: Download complete
# b45c209a4d67: Pull complete
# 3f5a608df989: Pull complete
# 11df60c3c446: Pull complete
# 3306300f7441: Pull complete
# d5f61fd90197: Pull complete
# 3c91cee49561: Pull complete
# 3166a3588baf: Pull complete
# 386667a0fc79: Pull complete
# Digest: sha256:9c4f76b334a5add8bd2862ff33289658d267ba298f2d2424fa1a28a4e4cc2232
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210301.v1@sha256:9c4f76b334a5add8bd2862ff33289658d267ba298f2d2424fa1a28a4e4cc2232
#  ---> 821000375236
# Step 2/18 : USER root
#  ---> Running in 811f77583df7
# Removing intermediate container 811f77583df7
#  ---> 74ce511a573a
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in 9439b8c4b658
# Removing intermediate container 9439b8c4b658
#  ---> 4022317e701b
# Step 4/18 : WORKDIR /
#  ---> Running in dee866792ef6
# Removing intermediate container dee866792ef6
#  ---> 22fd5122dc81
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> efae9def1219
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 757e528086c5
# Removing intermediate container 757e528086c5
#  ---> 469d61cd8619
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> fb3c97cf1ec4
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_582fb3ded767891f4847113530a5ccff -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 71abd1f01826
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# intel-openmp-2021.2. | 1.3 MB    |            |   0%
# intel-openmp-2021.2. | 1.3 MB    | 4          |   5%
# intel-openmp-2021.2. | 1.3 MB    | ########## | 100%
#
# ncurses-6.0          | 781 KB    |            |   0%
# ncurses-6.0          | 781 KB    | ########## | 100%
# ncurses-6.0          | 781 KB    | ########## | 100%
#
# joblib-1.0.1         | 208 KB    |            |   0%
# joblib-1.0.1         | 208 KB    | ########## | 100%
#
# xz-5.2.5             | 341 KB    |            |   0%
# xz-5.2.5             | 341 KB    | ########## | 100%
#
# scikit-learn-0.24.2  | 5.2 MB    |            |   0%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
# scikit-learn-0.24.2  | 5.2 MB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 3.1 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 3.1 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 3.1 MB    | ########## | 100%
#
# pip-21.1.1           | 1.8 MB    |            |   0%
# pip-21.1.1           | 1.8 MB    | ########## | 100%
# pip-21.1.1           | 1.8 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# threadpoolctl-2.1.0  | 17 KB     |            |   0%
# threadpoolctl-2.1.0  | 17 KB     | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1006 KB   |            |   0%
# libgfortran-ng-7.3.0 | 1006 KB   | ########## | 100%
#
# sqlite-3.23.1        | 808 KB    |            |   0%
# sqlite-3.23.1        | 808 KB    | ########## | 100%
#
# scipy-1.5.2          | 14.4 MB   |            |   0%
# scipy-1.5.2          | 14.4 MB   | ###1       |  32%
# scipy-1.5.2          | 14.4 MB   | #########  |  91%
# scipy-1.5.2          | 14.4 MB   | ########## | 100%
#
# numpy-1.19.2         | 22 KB     |            |   0%
# numpy-1.19.2         | 22 KB     | ########## | 100%
#
# certifi-2021.5.30    | 139 KB    |            |   0%
# certifi-2021.5.30    | 139 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 5.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 5.1 MB    | ########## | 100%
# libgcc-ng-9.1.0      | 5.1 MB    | ########## | 100%
#
# _libgcc_mutex-0.1    | 3 KB      |            |   0%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
#
# mkl_random-1.1.1     | 327 KB    |            |   0%
# mkl_random-1.1.1     | 327 KB    | ########## | 100%
#
# setuptools-52.0.0    | 724 KB    |            |   0%
# setuptools-52.0.0    | 724 KB    | ########## | 100%
# setuptools-52.0.0    | 724 KB    | ########## | 100%
#
# libedit-3.1          | 151 KB    |            |   0%
# libedit-3.1          | 151 KB    | ########## | 100%
#
# tk-8.6.10            | 3.0 MB    |            |   0%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
# tk-8.6.10            | 3.0 MB    | ########## | 100%
#
# python-3.6.2         | 23.6 MB   |            |   0%
# python-3.6.2         | 23.6 MB   | #8         |  18%
# python-3.6.2         | 23.6 MB   | #####6     |  56%
# python-3.6.2         | 23.6 MB   | #########2 |  93%
# python-3.6.2         | 23.6 MB   | ########## | 100%
#
# readline-7.0         | 848 KB    |            |   0%
# readline-7.0         | 848 KB    | ########## | 100%
#
# mkl-2020.2           | 138.3 MB  |            |   0%
# mkl-2020.2           | 138.3 MB  | 3          |   4%
# mkl-2020.2           | 138.3 MB  | 9          |  10%
# mkl-2020.2           | 138.3 MB  | #5         |  16%
# mkl-2020.2           | 138.3 MB  | ##1        |  21%
# mkl-2020.2           | 138.3 MB  | ##7        |  28%
# mkl-2020.2           | 138.3 MB  | ###3       |  34%
# mkl-2020.2           | 138.3 MB  | ###9       |  40%
# mkl-2020.2           | 138.3 MB  | ####6      |  46%
# mkl-2020.2           | 138.3 MB  | #####2     |  52%
# mkl-2020.2           | 138.3 MB  | #####8     |  58%
# mkl-2020.2           | 138.3 MB  | ######4    |  64%
# mkl-2020.2           | 138.3 MB  | #######    |  71%
# mkl-2020.2           | 138.3 MB  | #######6   |  77%
# mkl-2020.2           | 138.3 MB  | ########3  |  83%
# mkl-2020.2           | 138.3 MB  | ########9  |  90%
# mkl-2020.2           | 138.3 MB  | #########5 |  96%
# mkl-2020.2           | 138.3 MB  | ########## | 100%
# libffi-3.2.1         | 48 KB     |            |   0%
# libffi-3.2.1         | 48 KB     | ########## | 100%
#
# zlib-1.2.11          | 103 KB    |            |   0%
# zlib-1.2.11          | 103 KB    | ########## | 100%
#
# openssl-1.0.2u       | 2.2 MB    |            |   0%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
# openssl-1.0.2u       | 2.2 MB    | ########## | 100%
#
# six-1.15.0           | 27 KB     |            |   0%
# six-1.15.0           | 27 KB     | ########## | 100%
#
# mkl_fft-1.3.0        | 170 KB    |            |   0%
# mkl_fft-1.3.0        | 170 KB    | ########## | 100%
#
# numpy-base-1.19.2    | 4.1 MB    |            |   0%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
# numpy-base-1.19.2    | 4.1 MB    | ########## | 100%
#
# wheel-0.36.2         | 33 KB     |            |   0%
# wheel-0.36.2         | 33 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 52 KB     |            |   0%
# mkl-service-2.3.0    | 52 KB     | ########## | 100%
#
# ca-certificates-2021 | 112 KB    |            |   0%
# ca-certificates-2021 | 112 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working...
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_582fb3ded767891f4847113530a5ccff/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.qr1gekof.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.29.0-py3-none-any.whl (3.1 kB)
# Collecting xgboost
#   Downloading xgboost-1.4.2-py3-none-manylinux2010_x86_64.whl (166.7 MB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.29.0
#   Downloading azureml_dataset_runtime-1.29.0-py3-none-any.whl (3.5 kB)
# Collecting gunicorn==20.1.0
#   Downloading gunicorn-20.1.0-py3-none-any.whl (79 kB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting azureml-core~=1.29.0
#   Downloading azureml_core-1.29.0.post1-py3-none-any.whl (2.2 MB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Requirement already satisfied: six>=1.10 in /azureml-envs/azureml_582fb3ded767891f4847113530a5ccff/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.qr1gekof.requirements.txt (line 1)) (1.15.0)
# Collecting pytz>=2017.2
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting python-dateutil>=2.5.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Requirement already satisfied: numpy>=1.13.0 in /azureml-envs/azureml_582fb3ded767891f4847113530a5ccff/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.qr1gekof.requirements.txt (line 1)) (1.19.2)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting adal>=0.4.5
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Collecting requests>=2.17.3
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-3.0.1-py3-none-any.whl (133 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting click>=5.1
#   Downloading click-8.0.1-py3-none-any.whl (97 kB)
# Requirement already satisfied: setuptools>=3.0 in /azureml-envs/azureml_582fb3ded767891f4847113530a5ccff/lib/python3.6/site-packages (from gunicorn==20.1.0->azureml-defaults->-r /azureml-environment-setup/condaenv.qr1gekof.requirements.txt (line 1)) (52.0.0.post20210125)
# Collecting cryptography>=1.1.0
#   Downloading cryptography-3.4.7-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting PyJWT<3,>=1.0.0
#   Downloading PyJWT-2.1.0-py3-none-any.whl (16 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.5-py2.py3-none-any.whl (138 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting docker<5.0.0
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting contextlib2<1.0.0
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.0.0-py2.py3-none-any.whl (663 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.2.2-py2.py3-none-any.whl (21 kB)
# Collecting azure-core<2.0.0,>=1.9.0
#   Downloading azure_core-1.14.0-py2.py3-none-any.whl (136 kB)
# Collecting azureml-dataprep<2.16.0a,>=2.15.0a
#   Downloading azureml_dataprep-2.15.1-py3-none-any.whl (39.4 MB)
# Collecting pyarrow<4.0.0,>=0.17.0
#   Downloading pyarrow-3.0.0-cp36-cp36m-manylinux2014_x86_64.whl (20.7 MB)
# Collecting fusepy<4.0.0,>=3.0.1
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting azureml-dataprep-rslex<1.14.0a,>=1.13.0dev0
#   Downloading azureml_dataprep_rslex-1.13.0-cp36-cp36m-manylinux2010_x86_64.whl (9.8 MB)
# Collecting azureml-dataprep-native<34.0.0,>=33.0.0
#   Downloading azureml_dataprep_native-33.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.12.0-py2.py3-none-any.whl (66 kB)
# Collecting importlib-metadata
#   Downloading importlib_metadata-4.4.0-py3-none-any.whl (17 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.0.1-py2.py3-none-any.whl (68 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.0.1-cp36-cp36m-manylinux2010_x86_64.whl (30 kB)
# Collecting portalocker~=1.0
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /azureml-envs/azureml_582fb3ded767891f4847113530a5ccff/lib/python3.6/site-packages (from msrest<1.0.0,>=0.5.1->azureml-core~=1.29.0->azureml-defaults->-r /azureml-environment-setup/condaenv.qr1gekof.requirements.txt (line 1)) (2021.5.30)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting ruamel.yaml.clib>=0.1.2
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Requirement already satisfied: scipy in /azureml-envs/azureml_582fb3ded767891f4847113530a5ccff/lib/python3.6/site-packages (from xgboost->-r /azureml-environment-setup/condaenv.qr1gekof.requirements.txt (line 2)) (1.5.2)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting typing-extensions>=3.6.4
#   Downloading typing_extensions-3.10.0.0-py3-none-any.whl (26 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3923 sha256=ce08fedd28671c4362c75f62ce14da14f7841e468bcdf53f6b3d7e8e9ff58685
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10502 sha256=d4f958d7f907deb8155a9a15a62a74911a7b23d7220d802dd959f2eb416265bd
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11731 sha256=fdc71a4312b4e936b4bde41895565e0cd3777326ce65f36715d8a0493ed1af41
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: pycparser, cffi, urllib3, PyJWT, idna, cryptography, chardet, requests, portalocker, oauthlib, msal, requests-oauthlib, python-dateutil, msal-extensions, isodate, distro, azure-core, zipp, typing-extensions, msrest, dotnetcore2, cloudpickle, azureml-dataprep-rslex, azureml-dataprep-native, azure-identity, adal, websocket-client, ruamel.yaml.clib, pytz, pyopenssl, pyasn1, pyarrow, msrestazure, MarkupSafe, jeepney, importlib-metadata, backports.weakref, azureml-dataprep, azure-mgmt-core, azure-common, werkzeug, SecretStorage, ruamel.yaml, pathspec, pandas, ndg-httpsclient, liac-arff, jsonpickle, jmespath, Jinja2, itsdangerous, fusepy, docker, dill, contextlib2, click, backports.tempfile, azureml-dataset-runtime, azure-mgmt-storage, azure-mgmt-resource, azure-mgmt-keyvault, azure-mgmt-containerregistry, azure-mgmt-authorization, azure-graphrbac, json-logging-py, gunicorn, flask, configparser, azureml-model-management-sdk, azureml-core, applicationinsights, xgboost, azureml-defaults
# Successfully installed Jinja2-3.0.1 MarkupSafe-2.0.1 PyJWT-2.1.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.14.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.0.0 azure-mgmt-core-1.2.2 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-core-1.29.0.post1 azureml-dataprep-2.15.1 azureml-dataprep-native-33.0.0 azureml-dataprep-rslex-1.13.0 azureml-dataset-runtime-1.29.0 azureml-defaults-1.29.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-8.0.1 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.7 dill-0.3.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-20.1.0 idna-2.10 importlib-metadata-4.4.0 isodate-0.6.0 itsdangerous-2.0.1 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.12.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 pandas-1.1.5 pathspec-0.8.1 portalocker-1.7.1 pyarrow-3.0.0 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 python-dateutil-2.8.1 pytz-2021.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.2 typing-extensions-3.10.0.0 urllib3-1.26.5 websocket-client-1.0.1 werkzeug-1.0.1 xgboost-1.4.2 zipp-3.4.1
#
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_582fb3ded767891f4847113530a5ccff
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# WARNING: /root/.conda/pkgs does not exist
#
# Removing intermediate container 71abd1f01826
#  ---> cbb913f39a4e
# Step 9/18 : ENV PATH /azureml-envs/azureml_582fb3ded767891f4847113530a5ccff/bin:$PATH
#  ---> Running in d7948396020a
# Removing intermediate container d7948396020a
#  ---> e7dc138d31d5
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 2805ad1c8508
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> e2626c2a3951
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_582fb3ded767891f4847113530a5ccff
#  ---> Running in 6b679f08391d
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 6b679f08391d
#  ---> efa5c1d249af
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_582fb3ded767891f4847113530a5ccff
#  ---> Running in e0566cbf2bcd
# Removing intermediate container e0566cbf2bcd
#  ---> 52a1d594ca40
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_582fb3ded767891f4847113530a5ccff/lib:$LD_LIBRARY_PATH
#  ---> Running in aed7bebb36cb
# Removing intermediate container aed7bebb36cb
#  ---> 11a8b2df76ef
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> ba470c3163fd
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in fa9f3c4b05ce
# Removing intermediate container fa9f3c4b05ce
#  ---> d5d83c29c13c
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 7067e0afcdb5
# Removing intermediate container 7067e0afcdb5
#  ---> 19e8a40f4602
# Step 18/18 : CMD ["bash"]
#  ---> Running in 514298dc8504
# Removing intermediate container 514298dc8504
#  ---> c8b1bcdbc4d4
# Successfully built c8b1bcdbc4d4
# Successfully tagged 07cc2896cc2c4ad8ac118370e8d5b86f.azurecr.io/azureml/azureml_90e3b2c1ba1430b5af6b1221ad0842c5:latest
# Successfully tagged 07cc2896cc2c4ad8ac118370e8d5b86f.azurecr.io/azureml/azureml_90e3b2c1ba1430b5af6b1221ad0842c5:1
# 2021/06/03 09:40:04 Successfully executed container: acb_step_0
# 2021/06/03 09:40:04 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/06/03 09:40:04 Pushing image: 07cc2896cc2c4ad8ac118370e8d5b86f.azurecr.io/azureml/azureml_90e3b2c1ba1430b5af6b1221ad0842c5:1, attempt 1
# The push refers to repository [07cc2896cc2c4ad8ac118370e8d5b86f.azurecr.io/azureml/azureml_90e3b2c1ba1430b5af6b1221ad0842c5]
# d8627242c40e: Preparing
# 66d4df445c1f: Preparing
# 2d0210cd2d1e: Preparing
# c3a31fcd1791: Preparing
# 45415435cdf7: Preparing
# edbe68088ea2: Preparing
# 90a81828271c: Preparing
# 98e4fc81fc2f: Preparing
# 5d4156a5a86d: Preparing
# 5a817c02ccf1: Preparing
# 08d6fac9c4d0: Preparing
# de5226ffdd67: Preparing
# 8d9f57db5cd6: Preparing
# 09de504e442b: Preparing
# f86a0c2bc4c2: Preparing
# cb3dceea19cb: Preparing
# f5257ad8a814: Preparing
# 9f10818f1f96: Preparing
# 27502392e386: Preparing
# c95d2191d777: Preparing
# edbe68088ea2: Waiting
# 90a81828271c: Waiting
# 5d4156a5a86d: Waiting
# 98e4fc81fc2f: Waiting
# 5a817c02ccf1: Waiting
# 08d6fac9c4d0: Waiting
# de5226ffdd67: Waiting
# 8d9f57db5cd6: Waiting
# f86a0c2bc4c2: Waiting
# 09de504e442b: Waiting
# cb3dceea19cb: Waiting
# 27502392e386: Waiting
# f5257ad8a814: Waiting
# c95d2191d777: Waiting
# 9f10818f1f96: Waiting
# d8627242c40e: Pushed
# c3a31fcd1791: Pushed
# 2d0210cd2d1e: Pushed
# 66d4df445c1f: Pushed
# edbe68088ea2: Pushed
# 90a81828271c: Pushed
# 98e4fc81fc2f: Pushed
# 5d4156a5a86d: Pushed
# 5a817c02ccf1: Pushed
# 08d6fac9c4d0: Pushed
# de5226ffdd67: Pushed
# 8d9f57db5cd6: Pushed
# cb3dceea19cb: Pushed

# %% [markdown]
# ## Best Model

# %%
import joblib
# Get your best run and save the model from that run.

best_hyperdrive_run = hyperdrive_run.get_best_run_by_primary_metric()
#best_hyperdrive_run_metrics = best_hyperdrive_run.get_metrics()

print("Best Run Metrics :", best_hyperdrive_run.get_metrics())

best_hyperdrive_run.download_file(
    best_hyperdrive_run.get_file_names()[-1],
    output_file_path="./outputs/"
)
best_hyperdrive_model = best_hyperdrive_run.register_model(
    model_name="best_hyperdrive_model",
    model_path="./outputs/best_hyperdrive_model.joblib",
    tags=best_hyperdrive_run.get_metrics()
)
# Out:
# Best Run Metrics : {'Regularization Strength:': 0.05, 'Max iterations:': 50, 'Accuracy': 0.9097622660596864}

# %% [markdown]
# ### Now compare against AutoML

# %%
from azureml.data.dataset_factory import TabularDatasetFactory
import pandas as pd

# Create TabularDataset using TabularDatasetFactory

#  path to URL 
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data"

#  read remote URL data to DataFrame
ds = TabularDatasetFactory.from_delimited_files(url)

# %%
from train import clean_data
from sklearn.model_selection import train_test_split

# Use the clean_data function to clean your data.
x, y = clean_data(ds)

#automl settings have the optios to assign the dataframe and identify a target variable within it.
datafinal = pd.concat([x,y], axis = 1)
datafinal.head()

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from azureml.train.automl import AutoMLConfig

# Set parameters for AutoMLConfig
# NOTE: DO NOT CHANGE THE experiment_timeout_minutes PARAMETER OR YOUR INSTANCE WILL TIME OUT.
# If you wish to run the experiment longer, you will need to run this notebook in your own
# Azure tenant, which will incur personal costs.
automl_config = AutoMLConfig(
    experiment_timeout_minutes = 30,
    compute_target = compute_target,
    primary_metric = 'accuracy',
    n_cross_validations = 3, #typically 5, used to make time go quicker.
    task = 'classification',
    training_data = ds,
    label_column_name = 'y',
    enable_onnx_compatible_models = True)

# %%
# Submit your automl run
experiment = Experiment(ws, 'udacity_automl')
automl_run = experiment.submit(config = automl_config, show_output = True)
# Out:
# Running on remote.
# No run_configuration provided, running on cpu-cluster-01 with default configuration
# Running on remote compute: cpu-cluster-01
# Parent Run ID: AutoML_573ad1d1-40a4-457f-a797-cdccc223a339
#
# Current status: FeaturesGeneration. Generating features for the dataset.
# Current status: DatasetFeaturization. Beginning to fit featurizers and featurize the dataset.
# Current status: DatasetCrossValidationSplit. Generating individually featurized CV splits.
# Current status: ModelSelection. Beginning model selection.
#
# ****************************************************************************************************
# DATA GUARDRAILS:
#
# TYPE:         Class balancing detection
# STATUS:       ALERTED
# DESCRIPTION:  To decrease model bias, please cancel the current run and fix balancing problem.
#               Learn more about imbalanced data: https://aka.ms/AutomatedMLImbalancedData
# DETAILS:      Imbalanced data can lead to a falsely perceived positive effect of a model's accuracy because the input data has bias towards one class.
# +---------------------------------+---------------------------------+--------------------------------------+
# |Size of the smallest class       |Name/Label of the smallest class |Number of samples in the training data|
# +=================================+=================================+======================================+
# |3692                             |yes                              |32950                                 |
# +---------------------------------+---------------------------------+--------------------------------------+
#
# ****************************************************************************************************
#
# TYPE:         Missing feature values imputation
# STATUS:       PASSED
# DESCRIPTION:  No feature missing values were detected in the training data.
#               Learn more about missing value imputation: https://aka.ms/AutomatedMLFeaturization
#
# ****************************************************************************************************
#
# TYPE:         High cardinality feature detection
# STATUS:       PASSED
# DESCRIPTION:  Your inputs were analyzed, and no high cardinality features were detected.
#               Learn more about high cardinality feature handling: https://aka.ms/AutomatedMLFeaturization
#
# ****************************************************************************************************
#
# ****************************************************************************************************
# ITERATION: The iteration being evaluated.
# PIPELINE: A summary description of the pipeline being evaluated.
# DURATION: Time taken for the current iteration.
# METRIC: The result of computing score on the fitted pipeline.
# BEST: The best observed score thus far.
# ****************************************************************************************************
#
#  ITERATION   PIPELINE                                       DURATION      METRIC      BEST
#          0   MaxAbsScaler LightGBM                          0:00:58       0.9144    0.9144
#          1   MaxAbsScaler XGBoostClassifier                 0:01:12       0.9149    0.9149
#          2   MaxAbsScaler RandomForest                      0:00:51       0.8920    0.9149
#          3   MaxAbsScaler RandomForest                      0:00:51       0.8880    0.9149
#          4   MaxAbsScaler RandomForest                      0:00:48       0.8081    0.9149
#          5   MaxAbsScaler RandomForest                      0:00:46       0.7292    0.9149
#          6   SparseNormalizer XGBoostClassifier             0:01:09       0.9114    0.9149
#          7   MaxAbsScaler GradientBoosting                  0:01:12       0.9041    0.9149
#          8   StandardScalerWrapper RandomForest             0:00:54       0.9005    0.9149
#          9   MaxAbsScaler LogisticRegression                0:00:54       0.9085    0.9149
#         10   MaxAbsScaler ExtremeRandomTrees                0:02:12       0.8880    0.9149
#         11   SparseNormalizer XGBoostClassifier             0:01:11       0.9122    0.9149
#         12   MaxAbsScaler LightGBM                          0:05:28       0.8930    0.9149
#         13   MaxAbsScaler LightGBM                          0:00:58       0.9048    0.9149
#         14   SparseNormalizer XGBoostClassifier             0:02:16       0.9132    0.9149
#         15   StandardScalerWrapper LightGBM                 0:01:02       0.8952    0.9149
#         16   StandardScalerWrapper RandomForest             0:01:18       0.8880    0.9149
#         17   StandardScalerWrapper LightGBM                 0:00:47       0.8880    0.9149
#         18   SparseNormalizer XGBoostClassifier             0:01:01       0.9119    0.9149
#         19    VotingEnsemble                                0:01:22       0.9170    0.9170

# %%
pip install azureml-train-automl-runtime
# Out:
# Collecting azureml-train-automl-runtime
#   Downloading azureml_train_automl_runtime-1.18.0.post1-py3-none-any.whl (119 kB)
#      |████████████████████████████████| 119 kB 8.6 MB/s eta 0:00:01
# Collecting keras2onnx<=1.6.0,>=1.4.0
#   Downloading keras2onnx-1.6.0-py3-none-any.whl (219 kB)
#      |████████████████████████████████| 219 kB 10.9 MB/s eta 0:00:01
# Requirement already satisfied: statsmodels<=0.10.2,>=0.9.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (0.10.2)
# Collecting azureml-dataset-runtime[fuse,pandas]~=1.18.0
#   Downloading azureml_dataset_runtime-1.18.0-py3-none-any.whl (3.4 kB)
# Collecting skl2onnx==1.4.9
#   Downloading skl2onnx-1.4.9-py2.py3-none-any.whl (114 kB)
#      |████████████████████████████████| 114 kB 12.9 MB/s eta 0:00:01
# Requirement already satisfied: boto3<=1.15.18 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (1.15.18)
# Requirement already satisfied: scikit-learn<0.23.0,>=0.19.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (0.22.2.post1)
# Collecting onnxconverter-common<=1.6.0,>=1.4.2
#   Downloading onnxconverter_common-1.6.0-py2.py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 1.1 MB/s  eta 0:00:01
# Collecting onnxmltools==1.4.1
#   Downloading onnxmltools-1.4.1-py2.py3-none-any.whl (371 kB)
#      |████████████████████████████████| 371 kB 12.4 MB/s eta 0:00:01
# Collecting onnxruntime==1.3.0
#   Downloading onnxruntime-1.3.0-cp38-cp38-manylinux1_x86_64.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 15.2 MB/s eta 0:00:01
# Requirement already satisfied: scipy<=1.5.2,>=1.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (1.5.2)
# Requirement already satisfied: lightgbm<=2.3.0,>=2.0.11 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (2.3.0)
# Requirement already satisfied: azure-storage-queue~=12.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (12.1.5)
# Requirement already satisfied: pandas<1.0.0,>=0.21.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (0.25.3)
# Collecting azureml-automl-core~=1.18.0
#   Downloading azureml_automl_core-1.18.0.post2-py3-none-any.whl (186 kB)
#      |████████████████████████████████| 186 kB 102.0 MB/s eta 0:00:01
# Collecting azureml-train-automl-client~=1.18.0
#   Downloading azureml_train_automl_client-1.18.0-py3-none-any.whl (107 kB)
#      |████████████████████████████████| 107 kB 98.1 MB/s eta 0:00:01
# Requirement already satisfied: botocore<=1.18.18 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (1.18.18)
# Collecting azureml-automl-runtime~=1.18.0
#   Downloading azureml_automl_runtime-1.18.0.post2-py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 59.7 MB/s eta 0:00:01
# Collecting azureml-core~=1.18.0
#   Downloading azureml_core-1.18.0.post4-py3-none-any.whl (2.1 MB)
#      |████████████████████████████████| 2.1 MB 93.0 MB/s eta 0:00:01
# Collecting azureml-telemetry~=1.18.0
#   Downloading azureml_telemetry-1.18.0.post1-py3-none-any.whl (30 kB)
# Collecting azureml-defaults~=1.18.0
#   Downloading azureml_defaults-1.18.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-interpret~=1.18.0
#   Downloading azureml_interpret-1.18.0-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 4.5 MB/s  eta 0:00:01
# Requirement already satisfied: smart-open<=1.9.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (1.9.0)
# Requirement already satisfied: jinja2<=2.11.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (2.11.2)
# Requirement already satisfied: sklearn-pandas<=1.7.0,>=1.4.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (1.7.0)
# Requirement already satisfied: gensim<3.9.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (3.8.3)
# Requirement already satisfied: numpy<1.19.0,>=1.16.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-train-automl-runtime) (1.18.5)
# Collecting onnx<=1.7.0,>=1.5.0
#   Downloading onnx-1.7.0-cp38-cp38-manylinux1_x86_64.whl (7.4 MB)
#      |████████████████████████████████| 7.4 MB 85.7 MB/s eta 0:00:01
# Requirement already satisfied: requests in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras2onnx<=1.6.0,>=1.4.0->azureml-train-automl-runtime) (2.25.1)
# Requirement already satisfied: fire in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras2onnx<=1.6.0,>=1.4.0->azureml-train-automl-runtime) (0.4.0)
# Requirement already satisfied: protobuf in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras2onnx<=1.6.0,>=1.4.0->azureml-train-automl-runtime) (3.15.4)
# Requirement already satisfied: patsy>=0.4.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from statsmodels<=0.10.2,>=0.9.0->azureml-train-automl-runtime) (0.5.1)
# Collecting azureml-dataprep<2.5.0a,>=2.4.0a
#   Downloading azureml_dataprep-2.4.5-py3-none-any.whl (28.2 MB)
#      |████████████████████████████████| 28.2 MB 30.5 MB/s eta 0:00:01
# Requirement already satisfied: pyarrow<2.0.0,>=0.17.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.18.0->azureml-train-automl-runtime) (1.0.1)
# Requirement already satisfied: fusepy<4.0.0,>=3.0.1; extra == "fuse" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataset-runtime[fuse,pandas]~=1.18.0->azureml-train-automl-runtime) (3.0.1)
# Requirement already satisfied: six in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from skl2onnx==1.4.9->azureml-train-automl-runtime) (1.15.0)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from boto3<=1.15.18->azureml-train-automl-runtime) (0.3.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from boto3<=1.15.18->azureml-train-automl-runtime) (0.10.0)
# Requirement already satisfied: joblib>=0.11 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-learn<0.23.0,>=0.19.0->azureml-train-automl-runtime) (0.14.1)
# Requirement already satisfied: msrest>=0.6.10 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-storage-queue~=12.1->azureml-train-automl-runtime) (0.6.21)
# Requirement already satisfied: azure-core<2.0.0,>=1.10.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-storage-queue~=12.1->azureml-train-automl-runtime) (1.11.0)
# Requirement already satisfied: cryptography>=2.1.4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-storage-queue~=12.1->azureml-train-automl-runtime) (3.2)
# Requirement already satisfied: pytz>=2017.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pandas<1.0.0,>=0.21.0->azureml-train-automl-runtime) (2021.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pandas<1.0.0,>=0.21.0->azureml-train-automl-runtime) (2.8.1)
# Requirement already satisfied: urllib3<1.26,>=1.20; python_version != "3.4" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from botocore<=1.18.18->azureml-train-automl-runtime) (1.25.11)
# Requirement already satisfied: psutil<6.0.0,>=5.2.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-automl-runtime~=1.18.0->azureml-train-automl-runtime) (5.8.0)
# Requirement already satisfied: dill<0.4.0,>=0.2.8 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-automl-runtime~=1.18.0->azureml-train-automl-runtime) (0.3.3)
# Requirement already satisfied: pmdarima==1.1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-automl-runtime~=1.18.0->azureml-train-automl-runtime) (1.1.1)
# Collecting nimbusml<=1.8.0,>=1.7.1
#   Downloading nimbusml-1.8.0-cp38-none-manylinux1_x86_64.whl (114.1 MB)
#      |████████████████████████████████| 114.1 MB 67 kB/s s eta 0:00:01
# Requirement already satisfied: py-cpuinfo==5.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-automl-runtime~=1.18.0->azureml-train-automl-runtime) (5.0.0)
# Requirement already satisfied: SecretStorage in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (3.3.1)
# Requirement already satisfied: ndg-httpsclient in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (0.5.1)
# Requirement already satisfied: msrestazure>=0.4.33 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (0.6.4)
# Requirement already satisfied: azure-mgmt-keyvault<7.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (2.2.0)
# Requirement already satisfied: docker in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (4.4.4)
# Requirement already satisfied: azure-mgmt-storage<16.0.0,>=1.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (11.2.0)
# Requirement already satisfied: pathspec in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (0.8.1)
# Requirement already satisfied: PyJWT<2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (1.7.1)
# Requirement already satisfied: azure-common>=1.1.12 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (1.1.26)
# Requirement already satisfied: azure-mgmt-authorization<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (0.61.0)
# Requirement already satisfied: azure-graphrbac<1.0.0,>=0.40.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (0.61.1)
# Requirement already satisfied: adal>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (1.2.6)
# Requirement already satisfied: azure-mgmt-resource<15.0.0,>=1.2.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (12.0.0)
# Requirement already satisfied: jsonpickle in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (2.0.0)
# Requirement already satisfied: backports.tempfile in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (1.0)
# Requirement already satisfied: ruamel.yaml>=0.15.35 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (0.16.12)
# Requirement already satisfied: contextlib2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (0.6.0.post1)
# Collecting pyopenssl<20.0.0
#   Downloading pyOpenSSL-19.1.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.3 MB/s  eta 0:00:01
# Requirement already satisfied: azure-mgmt-containerregistry>=2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-core~=1.18.0->azureml-train-automl-runtime) (2.8.0)
# Requirement already satisfied: applicationinsights in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-telemetry~=1.18.0->azureml-train-automl-runtime) (0.11.9)
# Requirement already satisfied: werkzeug<=1.0.1,>=0.16.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-defaults~=1.18.0->azureml-train-automl-runtime) (1.0.1)
# Requirement already satisfied: configparser==3.7.4 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-defaults~=1.18.0->azureml-train-automl-runtime) (3.7.4)
# Requirement already satisfied: flask==1.0.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-defaults~=1.18.0->azureml-train-automl-runtime) (1.0.3)
# Requirement already satisfied: json-logging-py==0.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-defaults~=1.18.0->azureml-train-automl-runtime) (0.2)
# Requirement already satisfied: azureml-model-management-sdk==1.0.1b6.post1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-defaults~=1.18.0->azureml-train-automl-runtime) (1.0.1b6.post1)
# Requirement already satisfied: gunicorn==19.9.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-defaults~=1.18.0->azureml-train-automl-runtime) (19.9.0)
# Collecting interpret-community==0.15.*
#   Downloading interpret_community-0.15.4-py3-none-any.whl (5.9 MB)
#      |████████████████████████████████| 5.9 MB 103.4 MB/s eta 0:00:01
# Requirement already satisfied: boto>=2.32 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from smart-open<=1.9.0->azureml-train-automl-runtime) (2.49.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from jinja2<=2.11.2->azureml-train-automl-runtime) (1.1.1)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnx<=1.7.0,>=1.5.0->azureml-train-automl-runtime) (3.7.4.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->keras2onnx<=1.6.0,>=1.4.0->azureml-train-automl-runtime) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->keras2onnx<=1.6.0,>=1.4.0->azureml-train-automl-runtime) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->keras2onnx<=1.6.0,>=1.4.0->azureml-train-automl-runtime) (2.10)
# Requirement already satisfied: termcolor in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from fire->keras2onnx<=1.6.0,>=1.4.0->azureml-train-automl-runtime) (1.1.0)
# Requirement already satisfied: dotnetcore2<3.0.0,>=2.1.14 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse,pandas]~=1.18.0->azureml-train-automl-runtime) (2.1.20)
# Requirement already satisfied: cloudpickle<2.0.0,>=1.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse,pandas]~=1.18.0->azureml-train-automl-runtime) (1.6.0)
# Requirement already satisfied: azure-identity<1.5.0,>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse,pandas]~=1.18.0->azureml-train-automl-runtime) (1.4.1)
# Collecting azureml-dataprep-rslex<1.3.0a,>=1.2.0dev0
#   Downloading azureml_dataprep_rslex-1.2.3-cp38-cp38-manylinux2010_x86_64.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 52.3 MB/s eta 0:00:01
# Collecting azureml-dataprep-native<25.0.0,>=24.0.0
#   Downloading azureml_dataprep_native-24.0.0-cp38-cp38-manylinux1_x86_64.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 54.2 MB/s eta 0:00:01
# Requirement already satisfied: isodate>=0.6.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msrest>=0.6.10->azure-storage-queue~=12.1->azureml-train-automl-runtime) (0.6.0)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msrest>=0.6.10->azure-storage-queue~=12.1->azureml-train-automl-runtime) (1.3.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from cryptography>=2.1.4->azure-storage-queue~=12.1->azureml-train-automl-runtime) (1.14.5)
# Requirement already satisfied: Cython>=0.29 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pmdarima==1.1.1->azureml-automl-runtime~=1.18.0->azureml-train-automl-runtime) (0.29.21)
# Requirement already satisfied: jeepney>=0.6 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from SecretStorage->azureml-core~=1.18.0->azureml-train-automl-runtime) (0.6.0)
# Requirement already satisfied: pyasn1>=0.1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ndg-httpsclient->azureml-core~=1.18.0->azureml-train-automl-runtime) (0.4.8)
# Requirement already satisfied: websocket-client>=0.32.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from docker->azureml-core~=1.18.0->azureml-train-automl-runtime) (0.58.0)
# Requirement already satisfied: backports.weakref in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from backports.tempfile->azureml-core~=1.18.0->azureml-train-automl-runtime) (1.0.post1)
# Requirement already satisfied: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.9" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from ruamel.yaml>=0.15.35->azureml-core~=1.18.0->azureml-train-automl-runtime) (0.2.2)
# Requirement already satisfied: click>=5.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from flask==1.0.3->azureml-defaults~=1.18.0->azureml-train-automl-runtime) (7.1.2)
# Requirement already satisfied: itsdangerous>=0.24 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from flask==1.0.3->azureml-defaults~=1.18.0->azureml-train-automl-runtime) (1.1.0)
# Requirement already satisfied: liac-arff>=2.1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults~=1.18.0->azureml-train-automl-runtime) (2.5.0)
# Requirement already satisfied: interpret-core[required]<=0.2.1,>=0.1.20 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from interpret-community==0.15.*->azureml-interpret~=1.18.0->azureml-train-automl-runtime) (0.2.1)
# Requirement already satisfied: shap<=0.34.0,>=0.20.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from interpret-community==0.15.*->azureml-interpret~=1.18.0->azureml-train-automl-runtime) (0.34.0)
# Requirement already satisfied: packaging in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from interpret-community==0.15.*->azureml-interpret~=1.18.0->azureml-train-automl-runtime) (20.9)
# Requirement already satisfied: distro>=1.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from dotnetcore2<3.0.0,>=2.1.14->azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse,pandas]~=1.18.0->azureml-train-automl-runtime) (1.5.0)
# Requirement already satisfied: msal-extensions~=0.2.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse,pandas]~=1.18.0->azureml-train-automl-runtime) (0.2.2)
# Requirement already satisfied: msal<2.0.0,>=1.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse,pandas]~=1.18.0->azureml-train-automl-runtime) (1.9.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.10->azure-storage-queue~=12.1->azureml-train-automl-runtime) (3.1.0)
# Requirement already satisfied: pycparser in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.1.4->azure-storage-queue~=12.1->azureml-train-automl-runtime) (2.20)
# Requirement already satisfied: tqdm>4.25.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from shap<=0.34.0,>=0.20.0->interpret-community==0.15.*->azureml-interpret~=1.18.0->azureml-train-automl-runtime) (4.58.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from packaging->interpret-community==0.15.*->azureml-interpret~=1.18.0->azureml-train-automl-runtime) (2.4.7)
# Requirement already satisfied: portalocker~=1.0; platform_system != "Windows" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from msal-extensions~=0.2.2->azure-identity<1.5.0,>=1.2.0->azureml-dataprep<2.5.0a,>=2.4.0a->azureml-dataset-runtime[fuse,pandas]~=1.18.0->azureml-train-automl-runtime) (1.7.1)
# ERROR: azureml-widgets 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-widgets 1.24.0 has requirement azureml-telemetry~=1.24.0, but you'll have azureml-telemetry 1.18.0.post1 which is incompatible.
# ERROR: azureml-train-core 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-train-core 1.24.0 has requirement azureml-telemetry~=1.24.0, but you'll have azureml-telemetry 1.18.0.post1 which is incompatible.
# ERROR: azureml-tensorboard 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-sdk 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-sdk 1.24.0 has requirement azureml-dataset-runtime[fuse]~=1.24.0, but you'll have azureml-dataset-runtime 1.18.0 which is incompatible.
# ERROR: azureml-sdk 1.24.0 has requirement azureml-train-automl-client~=1.24.0, but you'll have azureml-train-automl-client 1.18.0 which is incompatible.
# ERROR: azureml-pipeline-steps 1.24.0 has requirement azureml-train-automl-client~=1.24.0, but you'll have azureml-train-automl-client 1.18.0 which is incompatible.
# ERROR: azureml-pipeline-core 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-opendatasets 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-opendatasets 1.24.0 has requirement azureml-dataset-runtime[fuse,pandas]~=1.24.0, but you'll have azureml-dataset-runtime 1.18.0 which is incompatible.
# ERROR: azureml-opendatasets 1.24.0 has requirement azureml-telemetry~=1.24.0, but you'll have azureml-telemetry 1.18.0.post1 which is incompatible.
# ERROR: azureml-opendatasets 1.24.0 has requirement scipy<=1.4.1,>=1.0.0, but you'll have scipy 1.5.2 which is incompatible.
# ERROR: azureml-mlflow 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-explain-model 1.24.0 has requirement azureml-interpret~=1.24.0, but you'll have azureml-interpret 1.18.0 which is incompatible.
# ERROR: azureml-datadrift 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-datadrift 1.24.0 has requirement azureml-dataset-runtime[fuse,pandas]~=1.24.0, but you'll have azureml-dataset-runtime 1.18.0 which is incompatible.
# ERROR: azureml-datadrift 1.24.0 has requirement azureml-telemetry~=1.24.0, but you'll have azureml-telemetry 1.18.0.post1 which is incompatible.
# ERROR: azureml-contrib-services 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-contrib-server 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-contrib-reinforcementlearning 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-contrib-pipeline-steps 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-contrib-pipeline-steps 1.24.0 has requirement azureml-dataset-runtime~=1.24.0, but you'll have azureml-dataset-runtime 1.18.0 which is incompatible.
# ERROR: azureml-contrib-notebook 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-contrib-gbdt 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-contrib-fairness 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-contrib-dataset 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-contrib-dataset 1.24.0 has requirement azureml-dataset-runtime[fuse,pandas]~=1.24.0, but you'll have azureml-dataset-runtime 1.18.0 which is incompatible.
# ERROR: azureml-cli-common 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# ERROR: azureml-accel-models 1.24.0 has requirement azureml-core~=1.24.0, but you'll have azureml-core 1.18.0.post4 which is incompatible.
# Installing collected packages: onnx, onnxconverter-common, keras2onnx, azureml-dataprep-rslex, azureml-dataprep-native, azureml-dataprep, azureml-dataset-runtime, skl2onnx, onnxmltools, onnxruntime, pyopenssl, azureml-core, azureml-telemetry, azureml-automl-core, azureml-train-automl-client, nimbusml, azureml-automl-runtime, azureml-defaults, interpret-community, azureml-interpret, azureml-train-automl-runtime
#   Attempting uninstall: azureml-dataprep-rslex
#     Found existing installation: azureml-dataprep-rslex 1.9.0
#     Uninstalling azureml-dataprep-rslex-1.9.0:
#       Successfully uninstalled azureml-dataprep-rslex-1.9.0
#   Attempting uninstall: azureml-dataprep-native
#     Found existing installation: azureml-dataprep-native 30.0.0
#     Uninstalling azureml-dataprep-native-30.0.0:
#       Successfully uninstalled azureml-dataprep-native-30.0.0
#   Attempting uninstall: azureml-dataprep
#     Found existing installation: azureml-dataprep 2.11.1
#     Uninstalling azureml-dataprep-2.11.1:
#       Successfully uninstalled azureml-dataprep-2.11.1
#   Attempting uninstall: azureml-dataset-runtime
#     Found existing installation: azureml-dataset-runtime 1.24.0
#     Uninstalling azureml-dataset-runtime-1.24.0:
#       Successfully uninstalled azureml-dataset-runtime-1.24.0
#   Attempting uninstall: pyopenssl
#     Found existing installation: pyOpenSSL 20.0.1
#     Uninstalling pyOpenSSL-20.0.1:
#       Successfully uninstalled pyOpenSSL-20.0.1
#   Attempting uninstall: azureml-core
#     Found existing installation: azureml-core 1.24.0
#     Uninstalling azureml-core-1.24.0:
#       Successfully uninstalled azureml-core-1.24.0
#   Attempting uninstall: azureml-telemetry
#     Found existing installation: azureml-telemetry 1.24.0
#     Uninstalling azureml-telemetry-1.24.0:
#       Successfully uninstalled azureml-telemetry-1.24.0
#   Attempting uninstall: azureml-automl-core
#     Found existing installation: azureml-automl-core 1.24.0
#     Uninstalling azureml-automl-core-1.24.0:
#       Successfully uninstalled azureml-automl-core-1.24.0
#   Attempting uninstall: azureml-train-automl-client
#     Found existing installation: azureml-train-automl-client 1.24.0
#     Uninstalling azureml-train-automl-client-1.24.0:
#       Successfully uninstalled azureml-train-automl-client-1.24.0
#   Attempting uninstall: azureml-defaults
#     Found existing installation: azureml-defaults 1.24.0
#     Uninstalling azureml-defaults-1.24.0:
#       Successfully uninstalled azureml-defaults-1.24.0
#   Attempting uninstall: interpret-community
#     Found existing installation: interpret-community 0.16.0
#     Uninstalling interpret-community-0.16.0:
#       Successfully uninstalled interpret-community-0.16.0
#   Attempting uninstall: azureml-interpret
#     Found existing installation: azureml-interpret 1.24.0
#     Uninstalling azureml-interpret-1.24.0:
#       Successfully uninstalled azureml-interpret-1.24.0
# Successfully installed azureml-automl-core-1.18.0.post2 azureml-automl-runtime-1.18.0.post2 azureml-core-1.18.0.post4 azureml-dataprep-2.4.5 azureml-dataprep-native-24.0.0 azureml-dataprep-rslex-1.2.3 azureml-dataset-runtime-1.18.0 azureml-defaults-1.18.0 azureml-interpret-1.18.0 azureml-telemetry-1.18.0.post1 azureml-train-automl-client-1.18.0 azureml-train-automl-runtime-1.18.0.post1 interpret-community-0.15.4 keras2onnx-1.6.0 nimbusml-1.8.0 onnx-1.7.0 onnxconverter-common-1.6.0 onnxmltools-1.4.1 onnxruntime-1.3.0 pyopenssl-19.1.0 skl2onnx-1.4.9
# Note: you may need to restart the kernel to use updated packages.

# %%
import azureml.train.automl

import azureml.automl.core
from azureml.automl.runtime.onnx_convert import OnnxConverter

best_automl_run, best_automl_onnx_model = automl_run.get_output(return_onnx_model = True)
OnnxConverter.save_onnx_model(best_automl_onnx_model, file_path = 'outputs/best_automl_model.onnx')

# %% [markdown]
# ## Model Deployment
#
# Remember you have to deploy only one of the two models you trained.. Perform the steps in the rest of this notebook only if you wish to deploy this model.
